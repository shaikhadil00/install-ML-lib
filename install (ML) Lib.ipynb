# %% [markdown]
# # how to see the jupyter notebook version

# %%
import jupyter_core

# %%
print(jupyter_core.__version__)
# Out:
# 4.11.1

# %% [markdown]
# # how to import Machine Learning Libraries in jupyter notebook

# %%
step:-
    1. open your command prompt or terminal
    
    2. type 'pip install 'with necessary library'

# %% [markdown]
# 1. pip install scikit-learn 'press Enter'
#
# 2. pip install pandas
#
# 3. pip install numpy
#
# 4. pip install matplotlib
#
# 5. pip install seaborn
#
# 6. pip install tensorflow
#
# 7. pip install keras
#
# 8. pip install scipy
#
# 9. pip install torch
#
# 10. pip install nltk
#
# 11. pip install opencv-python / openCV-python

# %% [markdown]
# # This is enough neccessary lib to perform operation

# %% [markdown]
# # To install any library use 'pip install'

# %% [markdown]
# ![Screenshot%202024-03-08%20125503.png](attachment:Screenshot%202024-03-08%20125503.png)

# %% [markdown]
# # This is for normal version Installation

# %% [markdown]
# # If u wannna to upgrade the version use this

# %% [markdown]
# ![Screenshot%202024-03-08%20122017.png](attachment:Screenshot%202024-03-08%20122017.png)

# %% [markdown]
# ![Screenshot%202024-03-08%20125138.png](attachment:Screenshot%202024-03-08%20125138.png)

# %% [markdown]
# ![Screenshot%202024-03-08%20125243.png](attachment:Screenshot%202024-03-08%20125243.png)

# %% [markdown]
# # while installation u cannot write or do simultaneously another installation

# %% [markdown]
# # Give u Error :- Operation cancelled by user

# %% [markdown]
# ![Screenshot%202024-03-08%20125313.png](attachment:Screenshot%202024-03-08%20125313.png)

# %% [markdown]
# # Now its done succesfully without any interrupt

# %% [markdown]
# ![Screenshot%202024-03-08%20125345.png](attachment:Screenshot%202024-03-08%20125345.png)

# %% [markdown]
# # Hence we conclude here with installation of neccessary library of (ML)
